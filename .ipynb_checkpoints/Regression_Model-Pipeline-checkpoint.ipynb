# %%
# !pip install mlxtend

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.1.1-py3-none-win_amd64.whl (54.4 MB)
# Requirement already satisfied: numpy in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from xgboost) (1.18.5)
# Requirement already satisfied: scipy in c:\users\deepti\anaconda3\envs\assignment\lib\site-packages (from xgboost) (1.4.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.1.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import itertools
import matplotlib.pyplot as plt

from sklearn import model_selection
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import metrics

# Classifiers
from sklearn.svm import SVR
# from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestRegressor
# from mlxtend.Regressor import StackingCVRegressor #
from mlxtend.regressor import StackingCVRegressor
import xgboost as xgb

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# Used to ignore warnings generated from StackingCVClassifier
import warnings
warnings.simplefilter('ignore')

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('datasets_52721_99691_student-mat.csv')

# %%
X = df.drop('G3', axis=1)
y = df[['G3']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
X_train.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 172     GP   M   17       U     LE3       T     4     4   teacher    other
# 119     GP   M   15       U     GT3       T     3     4     other    other
# 389     MS   F   18       U     GT3       T     1     1     other    other
# 198     GP   F   17       U     GT3       T     4     4  services  teacher
# 139     GP   F   15       U     GT3       T     4     4   teacher  teacher
#
#          reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 172  reputation   mother           1          2         0        no    yes
# 119  reputation   father           1          1         0        no     no
# 389      course   mother           2          2         1        no     no
# 198        home   mother           2          1         1        no    yes
# 139      course   mother           2          1         0        no     no
#
#     paid activities nursery higher internet romantic  famrel  freetime  goout  \
# 172  yes        yes     yes    yes      yes       no       4         4      4
# 119   no         no     yes    yes      yes       no       3         4      3
# 389   no        yes     yes    yes       no       no       1         1      1
# 198   no         no     yes    yes      yes       no       4         2      4
# 139   no        yes     yes    yes      yes       no       4         3      2
#
#      Dalc  Walc  health  absences  G1  G2
# 172     1     3       5         0  13  11
# 119     1     2       4         6  14  13
# 389     1     1       5         0   6   5
# 198     2     3       2        24  18  18
# 139     1     1       5         0  16  16

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

num_transform = Pipeline(steps=[('scaler', StandardScaler())])

cat_transform = Pipeline(steps=[('oneHot', OneHotEncoder(handle_unknown='ignore'))])

# %%
cat_features
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
num_features = df.select_dtypes(include=['int64', 'float64']).drop(['G3'], axis=1).columns
cat_features = df.select_dtypes(include=['object']).columns
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transform, num_features),
        ('cat', cat_transform, cat_features)])

# preprocessor = make_column_transformer(
#         (StandardScaler(), num_features),
#         (OneHotEncoder(handle_unknown='ignore'), cat_features))

# imputer_cat_pipeline = make_column_transformer(
#     (make_pipeline(SimpleImputer(strategy='constant'), cat_columns_fill_miss),
#     (make_pipeline(SimpleImputer(strategy='most_frequent'), cat_columns_fill_freq),
# )

# encoder_cat_pipeline = make_column_transformer(
#     (OrdinalEncoder(categories=ord_mapping), cat_columns_ord),
#     (OneHotEncoder(), cat_columns_onehot),
# )

# %%
from sklearn.linear_model import LinearRegression

rf = RandomForestRegressor(random_state = 1000, n_jobs = -1)
lr = LinearRegression(n_jobs = -1)

# %%
n_estimators = [int(x) for x in np.linspace(start = 20, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt',0.5]
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 3, 5,7]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
params = {
'stackingcvregressor__rf__n_estimators': n_estimators,  #randomforestregressor__bootstrap
               'stackingcvregressor__rf__max_features': max_features,
               'stackingcvregressor__rf__max_depth': max_depth,
               'stackingcvregressor__rf__min_samples_split': min_samples_split,
               'stackingcvregressor__rf__min_samples_leaf': min_samples_leaf,
               'stackingcvregressor__rf__bootstrap': bootstrap,
#               "xgbclassifier__n_estimators": [10, 50, 100, 500],
#                 "xgbclassifier__learning_rate": [0.1, 0.5, 1],
         }
print(params)
# Out:
# {'stackingcvregressor__rf__n_estimators': [20, 73, 126, 180, 233, 286, 340, 393, 446, 500], 'stackingcvregressor__rf__max_features': ['auto', 'sqrt', 0.5], 'stackingcvregressor__rf__max_depth': [5, 15, 26, 36, 47, 57, 68, 78, 89, 99, 110, None], 'stackingcvregressor__rf__min_samples_split': [2, 5, 10], 'stackingcvregressor__rf__min_samples_leaf': [1, 3, 5, 7], 'stackingcvregressor__rf__bootstrap': [True, False]}

# %%
stacking_model.get_params()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-8e8097ed9471> in <module>
# ----> 1 stacking_model.get_params()
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\regressor\stacking_cv_regression.py in get_params(self, deep)
#     283         # Return estimator parameter names for GridSearch support.
#     284         #
# --> 285         return self._get_params('named_regressors', deep=deep)
#     286
#     287     def set_params(self, **params):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\metaestimators.py in _get_params(self, attr, deep)
#      29         if not deep:
#      30             return out
# ---> 31         estimators = getattr(self, attr)
#      32         out.update(estimators)
#      33         for name, estimator in estimators:
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\regressor\stacking_cv_regression.py in named_regressors(self)
#     277         List of named estimator tuples, like [('svc', SVC(...))]
#     278         """
# --> 279         return _name_estimators(self.regressors)
#     280
#     281     def get_params(self, deep=True):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\externals\name_estimators.py in _name_estimators(estimators)
#      15     """Generate names for estimators."""
#      16
# ---> 17     names = [type(estimator).__name__.lower() for estimator in estimators]
#      18     namecount = defaultdict(int)
#      19     for _, name in zip(estimators, names):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\ensemble\_base.py in __iter__(self)
#     171     def __iter__(self):
#     172         """Return iterator over estimators in the ensemble."""
# --> 173         return iter(self.estimators_)
#     174
#     175
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'estimators_'

# %%
# rf_pipe = Pipeline(steps=[('preprocessor', preprocessor),
#                       ('classifier', rf)])

# rf_pipe = Pipeline(steps=[('preprocessor', preprocessor),
#                       ('classifier', c3)])

stacking_model = StackingCVRegressor(regressors=rf, 
                            meta_regressor=lr,
                            random_state=42)
pipe_stack = make_pipeline(preprocessor, stacking_model)

# pipe = Pipeline([
#     ('preprocessor', preprocessor),('stack',stacking_model)
# ])
# params = {'kneighborsclassifier__n_neighbors': [1, 5],
#           'randomforestclassifier__n_estimators': [10, 50],
#           'meta_classifier__C': [0.1, 10.0]}

grid = GridSearchCV(estimator=pipe_stack, 
                    param_grid=params, 
                    cv=3,
                    refit=True)
grid.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-65baca14325f> in <module>
#      21                     cv=3,
#      22                     refit=True)
# ---> 23 grid.fit(X_train, y_train)
#      24
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     713                                for parameters, (train, test)
#     714                                in product(candidate_params,
# --> 715                                           cv.split(X, y, groups)))
#     716
#     717                 if len(out) < 1:
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1027             # remaining jobs.
#    1028             self._iterating = False
# -> 1029             if self.dispatch_one_batch(iterator):
#    1030                 self._iterating = self._original_iterator is not None
#    1031
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     204     def apply_async(self, func, callback=None):
#     205         """Schedule a func to be run"""
# --> 206         result = ImmediateResult(func)
#     207         if callback:
#     208             callback(result)
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     568         # Don't delay the application, to avoid keeping the input
#     569         # arguments in memory
# --> 570         self.results = batch()
#     571
#     572     def get(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in __call__(self)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     252             return [func(*args, **kwargs)
# --> 253                     for func, args, kwargs in self.items]
#     254
#     255     def __reduce__(self):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     518             cloned_parameters[k] = clone(v, safe=False)
#     519
# --> 520         estimator = estimator.set_params(**cloned_parameters)
#     521
#     522     start_time = time.time()
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in set_params(self, **kwargs)
#     139         self
#     140         """
# --> 141         self._set_params('steps', **kwargs)
#     142         return self
#     143
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\metaestimators.py in _set_params(self, attr, **params)
#      51                 self._replace_estimator(attr, name, params.pop(name))
#      52         # 3. Step parameters and other initialisation arguments
# ---> 53         super().set_params(**params)
#      54         return self
#      55
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\base.py in set_params(self, **params)
#     241             # Simple optimization to gain speed (inspect is slow)
#     242             return self
# --> 243         valid_params = self.get_params(deep=True)
#     244
#     245         nested_params = defaultdict(dict)  # grouped by prefix
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\pipeline.py in get_params(self, deep)
#     128             Parameter names mapped to their values.
#     129         """
# --> 130         return self._get_params('steps', deep=deep)
#     131
#     132     def set_params(self, **kwargs):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\metaestimators.py in _get_params(self, attr, deep)
#      33         for name, estimator in estimators:
#      34             if hasattr(estimator, 'get_params'):
# ---> 35                 for key, value in estimator.get_params(deep=True).items():
#      36                     out['%s__%s' % (name, key)] = value
#      37         return out
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\regressor\stacking_cv_regression.py in get_params(self, deep)
#     283         # Return estimator parameter names for GridSearch support.
#     284         #
# --> 285         return self._get_params('named_regressors', deep=deep)
#     286
#     287     def set_params(self, **params):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\utils\metaestimators.py in _get_params(self, attr, deep)
#      29         if not deep:
#      30             return out
# ---> 31         estimators = getattr(self, attr)
#      32         out.update(estimators)
#      33         for name, estimator in estimators:
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\regressor\stacking_cv_regression.py in named_regressors(self)
#     277         List of named estimator tuples, like [('svc', SVC(...))]
#     278         """
# --> 279         return _name_estimators(self.regressors)
#     280
#     281     def get_params(self, deep=True):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\mlxtend\externals\name_estimators.py in _name_estimators(estimators)
#      15     """Generate names for estimators."""
#      16
# ---> 17     names = [type(estimator).__name__.lower() for estimator in estimators]
#      18     namecount = defaultdict(int)
#      19     for _, name in zip(estimators, names):
#
# ~\anaconda3\envs\Assignment\lib\site-packages\sklearn\ensemble\_base.py in __iter__(self)
#     171     def __iter__(self):
#     172         """Return iterator over estimators in the ensemble."""
# --> 173         return iter(self.estimators_)
#     174
#     175
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'estimators_'

# %%
cv_keys = ('mean_test_score', 'std_test_score', 'params')

for r, _ in enumerate(grid.cv_results_['mean_test_score']):
    print("%0.3f +/- %0.2f %r"
          % (grid.cv_results_[cv_keys[0]][r],
             grid.cv_results_[cv_keys[1]][r] / 2.0,
             grid.cv_results_[cv_keys[2]][r]))

print('Best parameters: %s' % grid.best_params_)
print('Accuracy: %.2f' % grid.best_score_)
